# %% [markdown]
# ## 練習時間
# 資料的操作有很多，接下來的馬拉松中我們會介紹常被使用到的操作，參加者不妨先自行想像一下，第一次看到資料，我們一般會想知道什麼訊息？
#
# #### Ex: 如何知道資料的 row 數以及 column 數、有什麼欄位、多少欄位、如何截取部分的資料等等
#
# 有了對資料的好奇之後，我們又怎麼通過程式碼來達成我們的目的呢？
#
# #### 可參考該[基礎教材](https://bookdata.readthedocs.io/en/latest/base/01_pandas.html#DataFrame-%E5%85%A5%E9%97%A8)或自行 google

# %%
import os
import numpy as np
import pandas as pd

# %%
# 設定 data_path
dir_data = '../data/'

# %%
f_app = os.path.join(dir_data, 'application_train.csv')
print('Path of read in data: %s' % (f_app))
app_train = pd.read_csv(f_app)
# Out:
# Path of read in data: ../data/application_train.csv

# %% [markdown]
# ### 如果沒有想法，可以先嘗試找出剛剛例子中提到的問題的答案
# #### 資料的 row 數以及 column 數

# %%
#資料的 row 數以及 column 數
Num_rows = app_train.shape[0]
Num_cols = app_train.shape[1]
print('Num_rows: %s  Num_cols: %s' % (Num_rows,Num_cols))
# Out:
# Num_rows: 307511  Num_cols: 122

# %% [markdown]
# #### 列出所有欄位

# %%
#列出所有欄位
list(app_train)
# Out:
# ['SK_ID_CURR',
#  'TARGET',
#  'NAME_CONTRACT_TYPE',
#  'CODE_GENDER',
#  'FLAG_OWN_CAR',
#  'FLAG_OWN_REALTY',
#  'CNT_CHILDREN',
#  'AMT_INCOME_TOTAL',
#  'AMT_CREDIT',
#  'AMT_ANNUITY',
#  'AMT_GOODS_PRICE',
#  'NAME_TYPE_SUITE',
#  'NAME_INCOME_TYPE',
#  'NAME_EDUCATION_TYPE',
#  'NAME_FAMILY_STATUS',
#  'NAME_HOUSING_TYPE',
#  'REGION_POPULATION_RELATIVE',
#  'DAYS_BIRTH',
#  'DAYS_EMPLOYED',
#  'DAYS_REGISTRATION',
#  'DAYS_ID_PUBLISH',
#  'OWN_CAR_AGE',
#  'FLAG_MOBIL',
#  'FLAG_EMP_PHONE',
#  'FLAG_WORK_PHONE',
#  'FLAG_CONT_MOBILE',
#  'FLAG_PHONE',
#  'FLAG_EMAIL',
#  'OCCUPATION_TYPE',
#  'CNT_FAM_MEMBERS',
#  'REGION_RATING_CLIENT',
#  'REGION_RATING_CLIENT_W_CITY',
#  'WEEKDAY_APPR_PROCESS_START',
#  'HOUR_APPR_PROCESS_START',
#  'REG_REGION_NOT_LIVE_REGION',
#  'REG_REGION_NOT_WORK_REGION',
#  'LIVE_REGION_NOT_WORK_REGION',
#  'REG_CITY_NOT_LIVE_CITY',
#  'REG_CITY_NOT_WORK_CITY',
#  'LIVE_CITY_NOT_WORK_CITY',
#  'ORGANIZATION_TYPE',
#  'EXT_SOURCE_1',
# ...

# %% [markdown]
# #### 截取部分資料

# %%
#選擇特定的欄位('NAME_CONTRACT_TYPE', 'AMT_CREDIT')，並且限縮在5:20之間
app_train.loc[5:20, ['NAME_CONTRACT_TYPE', 'AMT_CREDIT']]
# Out:
#    NAME_CONTRACT_TYPE  AMT_CREDIT
# 5          Cash loans    490495.5
# 6          Cash loans   1560726.0
# 7          Cash loans   1530000.0
# 8          Cash loans   1019610.0
# 9     Revolving loans    405000.0
# 10         Cash loans    652500.0
# 11         Cash loans    148365.0
# 12         Cash loans     80865.0
# 13         Cash loans    918468.0
# 14         Cash loans    773680.5
# 15         Cash loans    299772.0
# 16         Cash loans    509602.5
# 17    Revolving loans    270000.0
# 18    Revolving loans    157500.0
# 19         Cash loans    544491.0
# 20    Revolving loans    427500.0

# %%
#選擇特定的索引
app_train.iloc[3:5,6:12]
# Out:
#    CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# 3             0          135000.0    312682.5      29686.5         297000.0
# 4             0          121500.0    513000.0      21865.5         513000.0
#
#   NAME_TYPE_SUITE
# 3   Unaccompanied
# 4   Unaccompanied

# %% [markdown]
# #### 還有各種數之不盡的資料操作，重點還是取決於實務中遇到的狀況和你想問的問題，在馬拉松中我們也會陸續提到更多例子

# %%
####
--------------------------------------------------
檔名 : HomeCredit_columns_description.csv
解釋 : 
1.This file contains descriptions for the columns in the various data files.
--------------------------------------------------
--------------------------------------------------
檔名 : application_{train|test}.csv
解釋 : 
1.This is the main table, broken into two files for Train (with TARGET) and Test (without TARGET).
2.Static data for all applications. One row represents one loan in our data sample.
--------------------------------------------------
===================================
SK_ID_CURR | 貸款樣本 ID 
TARGET     | 目標客戶種類(-1 : 還款困難 ; 0 : 其他所有案例)
NAME_CONTRACT_TYPE | 貸款方式(現金或循環利率)
CODE_GENDER        | 客戶性別
FLAG_OWN_CAR       | 客戶有無擁有車子
FLAG_OWN_REALTY    | 客戶有無擁有房子
CNT_CHILDREN       | 客戶擁有幾個子女
AMT_INCOME_TOTAL   | 客戶的收入
AMT_CREDIT         | 貸款金額
AMT_ANNUITY        | 年金貸款
AMT_GOODS_PRICE    | 貸款貨物價格
NAME_TYPE_SUITE    | 誰是申請貸款時陪同客戶
NAME_INCOME_TYPE   | 客戶收入類型（商人，工作，產假等)
NAME_EDUCATION_TYPE| 客戶最高學歷
NAME_FAMILY_STATUS | 客戶家庭狀況
NAME_HOUSING_TYPE  | 客戶的住房情況如何（租房，與父母同住等）
REGION_POPULATION_RELATIVE | 客戶居住區域的人口密度（數字越大則人口稠密越高）
DAYS_BIRTH         | 客戶的申請天數
DAYS_EMPLOYED      | 客戶在申請前幾天開始就業
DAYS_REGISTRA+A20TION | 客戶在申請前幾天更換註冊
DAYS_ID_PUBLISH       | 客戶在申請前幾天更換申請貸款的身份證明文件
OWN_CAR_AGE           | 客戶車子的車齡
FLAG_MOBIL            | 客戶端是否提供手機（1 = 是，0 = 否）
FLAG_EMP_PHONE        | 客戶端是否提供工作電話（1 = 是，0 = 否）
FLAG_WORK_PHONE       | 客戶端是否提供家庭電話（1 = 是，0 = 否）
FLAG_CONT_MOBILE      | 手機是否可以通話（1 = 是，0 = 否）
FLAG_PHONE            | 客戶端是否提供家庭電話（1 = 是，0 = 否）
FLAG_EMAIL            | 客戶端是否提供電子郵件（1 = 是，0 = 否）
OCCUPATION_TYPE       | 客戶的工作職業
CNT_FAM_MEMBERS       | 客戶有多少家庭成員
REGION_RATING_CLIENT  | 我們對客戶所在地區的評級（1,2,3）
REGION_RATING_CLIENT_W_CITY | 我們對客戶所居住的地區的評級（1,2,3）
WEEKDAY_APPR_PROCESS_START  | 客戶在一周的哪一天申請貸款
HOUR_APPR_PROCESS_START     | 客戶申請貸款大約何時
REG_REGION_NOT_LIVE_REGION  | 客戶永久地址與聯繫地址不匹配（1 =不同，0 =相同，在地區級別）
REG_REGION_NOT_WORK_REGION  | 客戶永久地址與工作地址不匹配（1 =不同，0 =相同，在地區級別）
LIVE_REGION_NOT_WORK_REGION | 客戶聯繫地址與工作地址不符（1 = 不同，0 = 同一，區域一級）
REG_CITY_NOT_LIVE_CITY      | 客戶永久地址與聯繫地址不匹配（1 = 不同，0 = 相同，在城市級別）
REG_CITY_NOT_WORK_CITY      | 客戶永久地址與工作地址不匹配（1 = 不同，0 = 相同，在城市級別）
LIVE_CITY_NOT_WORK_CITY     | 客戶聯繫地址與工作地址不符（1 = 不同，0 = 相同，在城市一級）
ORGANIZATION_TYPE           | 客戶工作類型
EXT_SOURCE_1                | 來自外部數據源的標準化分數
EXT_SOURCE_2                | 來自外部數據源的標準化分數
EXT_SOURCE_3                | 來自外部數據源的標準化分數
APARTMENTS_AVG              | 公寓套房數量 : 關於建立客戶所在地的信息，平均值（_AVG），絕對值（_MODE），中位數（_MEDI）
BASEMENTAREA_AVG            | 地下室地面面積 : 關於建立客戶所在地的信息，平均值（_AVG），絕對值（_MODE），中位數（_MEDI）
YEARS_BEGINEXPLUATATION_AVG | 房屋投入使用年份 : 關於建立客戶所在地的信息，平均值（_AVG），絕對值（_MODE），中位數（_MEDI）
YEARS_BUILD_AVG             | 房屋修建年份 : 關於建立客戶所在地的信息，平均值（_AVG），絕對值（_MODE），中位數（_MEDI）
COMMONAREA_AVG              | 房屋總面積 : 關於建立客戶所在地的信息，平均值（_AVG），絕對值（_MODE），中位數（_MEDI）
ELEVATORS_AVG               | 電梯數量 : 關於建立客戶所在地的信息，平均值（_AVG），絕對值（_MODE），中位數（_MEDI）
ENTRANCES_AVG               | 入口數量 : 關於建立客戶所在地的信息，平均值（_AVG），絕對值（_MODE），中位數（_MEDI）
FLOORSMAX_AVG               | 最高樓層 : 關於建立客戶所在地的信息，平均值（_AVG），絕對值（_MODE），中位數（_MEDI）
FLOORSMIN_AVG               | 最低樓層 : 關於建立客戶所在地的信息，平均值（_AVG），絕對值（_MODE），中位數（_MEDI）
LANDAREA_AVG                | 土地面積 : 關於建立客戶所在地的信息，平均值（_AVG），絕對值（_MODE），中位數（_MEDI）
LIVINGAPARTMENTS_AVG        | 居住用房數量 : 關於建立客戶所在地的信息，平均值（_AVG），絕對值（_MODE），中位數（_MEDI）
LIVINGAREA_AVG              | 居住用房總面積 : 關於建立客戶所在地的信息，平均值（_AVG），絕對值（_MODE），中位數（_MEDI）
NONLIVINGAPARTMENTS_AVG     | 非居住用房數量 : 關於建立客戶所在地的信息，平均值（_AVG），絕對值（_MODE），中位數（_MEDI）
NONLIVINGAREA_AVG           | 非居住用房總面積 : 關於建立客戶所在地的信息，平均值（_AVG），絕對值（_MODE），中位數（_MEDI）
APARTMENTS_MODE             | 公寓套房數量
BASEMENTAREA_MODE           | 地下室地面面積
YEARS_BEGINEXPLUATATION_MODE| 房屋投入使用年份
YEARS_BUILD_MODE            | 房屋修建年份
COMMONAREA_MODE             | 房屋總面積
ELEVATORS_MODE              | 電梯數量
ENTRANCES_MODE              | 入口數量
FLOORSMAX_MODE              | 最高樓層
FLOORSMIN_MODE              | 最低樓層
LANDAREA_MODE               | 土地面積
LIVINGAPARTMENTS_MODE       | 居住用房數量
LIVINGAREA_MODE             | 非居住用房數量
NONLIVINGAPARTMENTS_MODE    | 非居住用房數量
NONLIVINGAREA_MODE          | 非居住空間
APARTMENTS_MEDI             | 公寓套房數量
BASEMENTAREA_MEDI           | 地下室地面面積
YEARS_BEGINEXPLUATATION_MEDI| 房屋投入使用年份
YEARS_BUILD_MEDI            | 房屋修建年份
COMMONAREA_MEDI             | 房屋總面積
ELEVATORS_MEDI              | 電梯數量
ENTRANCES_MEDI              | 入口數量
FLOORSMAX_MEDI              | 最高樓層
FLOORSMIN_MEDI              | 最低樓層
LANDAREA_MEDI               | 土地面積
LIVINGAPARTMENTS_MEDI       | 居住用房數量
LIVINGAREA_MEDI             | 居住用房總面積
NONLIVINGAPARTMENTS_MEDI    | 非居住用房數量
NONLIVINGAREA_MEDI          | 非居住用房總面積
FONDKAPREMONT_MODE          | 維修房屋基金收取方法
HOUSETYPE_MODE              | 房屋類型
TOTALAREA_MODE              | 樓房總面積
WALLSMATERIAL_MODE          | 牆壁材質
EMERGENCYSTATE_MODE         | 鑑定房屋為危樓
OBS_30_CNT_SOCIAL_CIRCLE    | 有多少在30天數內觀察客戶社會環境
DEF_30_CNT_SOCIAL_CIRCLE    | 有多少違約30天數內觀察客戶社會環境
OBS_60_CNT_SOCIAL_CIRCLE    | 有多少在60天數內觀察客戶社會環境
DEF_60_CNT_SOCIAL_CIRCLE    | 有多少違約60天數內觀察客戶社會環境
DAYS_LAST_PHONE_CHANGE      | 申請前多少天客戶換過電話
FLAG_DOCUMENT_2             | 客戶是否提供了文件2
FLAG_DOCUMENT_3             | 客戶是否提供了文件3
FLAG_DOCUMENT_4             | 客戶是否提供了文件4
FLAG_DOCUMENT_5             | 客戶是否提供了文件5
FLAG_DOCUMENT_6             | 客戶是否提供了文件6
FLAG_DOCUMENT_7             | 客戶是否提供了文件7
FLAG_DOCUMENT_8             | 客戶是否提供了文件8
FLAG_DOCUMENT_9             | 客戶是否提供了文件9
FLAG_DOCUMENT_10            | 客戶是否提供了文件10
FLAG_DOCUMENT_11            | 客戶是否提供了文件11
FLAG_DOCUMENT_12            | 客戶是否提供了文件12
FLAG_DOCUMENT_13            | 客戶是否提供了文件13
FLAG_DOCUMENT_14            | 客戶是否提供了文件14
FLAG_DOCUMENT_15            | 客戶是否提供了文件15
FLAG_DOCUMENT_16            | 客戶是否提供了文件16
FLAG_DOCUMENT_17            | 客戶是否提供了文件17
AMT_REQ_CREDIT_BUREAU_HOUR  | 申請前一小時向信用局詢問客戶的情況
AMT_REQ_CREDIT_BUREAU_DAY   | 申請前一天向信貸局詢問有關客戶的數目（不包括申請前一小時）
AMT_REQ_CREDIT_BUREAU_WEEK  | 申請前一周向信貸局詢問有關客戶的數目（不包括申請前一天）
AMT_REQ_CREDIT_BUREAU_MON   | 申請前一個月向信用局詢問客戶的數量（不包括申請前一周）
AMT_REQ_CREDIT_BUREAU_QRT   | 申請前3個月向信用局詢問客戶的數量（不包括申請前一個月）
AMT_REQ_CREDIT_BUREAU_YEAR  | 向信貸局詢問有關客戶的一天（不包括申請前最後3個月）
--------------------------------------------------
檔名 : bureau.csv
解釋 : 
1.All client's previous credits provided by other financial(財政) institutions(機構) that were reported to Credit Bureau(信貸局) (for clients who have a loan in our sample).
2.For every loan in our sample, there are as many rows as number of credits the client had in Credit Bureau before the application date.
--------------------------------------------------
SK_ID_CURR                  | 樣本貸款ID  - 我們樣本中的一筆貸款可以在信用局中擁有0,1,2或更多相關的先前信用
SK_BUREAU_ID                | 信貸局貸款與樣本貸款相關之ID（每個貸款申請的唯一編碼）
CREDIT_ACTIVE               | 信用局（CB）的狀況報告
CREDIT_CURRENCY             | 信用局信用記錄的貨幣
DAYS_CREDIT                 | 在當前申請之前多少天客戶申請信用局信貸
CREDIT_DAY_OVERDUE          | 在樣本申請相關貸款時，CB信用證的逾期天數
DAYS_CREDIT_ENDDATE         | 在歸屬信貸申請時剩餘的CB信用期（以天為單位）
DAYS_ENDDATE_FACT           | 家庭信貸申請時CB信用額結束以來的天數（僅限封閉式信貸）
AMT_CREDIT_MAX_OVERDUE      | 到目前為止，信用局信貸的最高金額已逾期
CNT_CREDIT_PROLONG          | 信用局信貸延長了多少次
AMT_CREDIT_SUM              | 信用局信貸的當前信貸額度
AMT_CREDIT_SUM_DEBT         | 信用局信貸的當前債務
AMT_CREDIT_SUM_LIMIT        | 信用局目前的信用卡信用額度
AMT_CREDIT_SUM_OVERDUE      | 信用局信貸逾期的當前金額
CREDIT_TYPE                 | 信用局信貸類型（汽車，現金，......）
DAYS_CREDIT_UPDATE          | 貸款申請前幾天有關信用局信貸的資訊
AMT_ANNUITY                 | 信用局年金信用額度
--------------------------------------------------
檔名 : bureau_balance.csv
解釋 : 
1.Monthly balances of previous credits in Credit Bureau.
2.This table has one row for each month of history of every previous credit reported to Credit Bureau – i.e the table has (#loans in sample * # of relative previous credits * # of months where we have some history observable for the previous credits) rows.
--------------------------------------------------
SK_BUREAU_ID                | 信用局信用的記錄ID（每個應用程序的唯一編碼） - 使用它來加入CREDIT BUREAU表
MONTHS_BALANCE              | 相對於申請日期的餘額月份（-1表示最新的餘額日期）
STATUS                      | 月內信用局貸款狀況（活動，關閉，DPD0-30，[C表示已關閉，X表示狀態未知，0表示沒有DPD，1表示在月份之間最大值為1-30,2表示DPD 31-60） ，5表示DPD 120+或出售或註銷]）
--------------------------------------------------
檔名 : POS_CASH_balance.csv
解釋 : 
1.Monthly balance snapshots(快照) of previous POS (point of sales) and cash loans that the applicant had with Home Credit.
2.This table has one row for each month of history of every previous credit in Home Credit (consumer credit and cash loans) related to loans in our sample – i.e. the table has (#loans in sample * # of relative previous credits * # of months in which we have some history observable for the previous credits) rows.
--------------------------------------------------
SK_ID_PREV                  | 在我們的樣本中與貸款相關的歸屬信貸中的先前信用的ID。（我們樣本中的一筆貸款可以擁有0,1,2或更多以前的房屋貸款貸款）
SK_ID_CURR                  | 樣本貸款ID
MONTHS_BALANCE              | 相對於應用程序日期的月份餘額（-1表示最新月度快照的信息，0表示應用程序中的信息)
CNT_INSTALMENT              | 以前的信用期限（可以隨時間變化）
CNT_INSTALMENT_FUTURE       | 分期付款用於支付之前的信用額度
NAME_CONTRACT_STATUS        | 本月的合約狀態
SK_DPD                      | DPD（逾期的天數）在前個月信用
SK_DPD_DEF                  | 該月的DPD具有先前信用的容忍度（低貸款金額的債務被忽略）
--------------------------------------------------
檔名 : credit_card_balance.csv
解釋 : 
1.Monthly balance snapshots of previous credit cards that the applicant has with Home Credit.
2.This table has one row for each month of history of every previous credit in Home Credit (consumer credit and cash loans) related to loans in our sample – i.e. the table has (#loans in sample * # of relative previous credit cards * # of months where we have some history observable for the previous credit card) rows.
--------------------------------------------------
SK_ID_PREV                  | 樣本貸款相關的歸屬信貸的先前信用的ID。 （我們樣本中的一筆貸款可以擁有0,1,2或更多以前的房屋貸款貸款）
SK_ID_CURR                  | 樣本貸款ID
MONTHS_BALANCE              | 相對於申請日期的餘額月份（-1表示最新的餘額日期）
AMT_BALANCE                 | 在上一個信用月份結餘
AMT_CREDIT_LIMIT_ACTUAL     | 在上一個信用月份的信用卡限額
AMT_DRAWINGS_ATM_CURRENT    | 在上一個信用額的月份在ATM上提取的金額
AMT_DRAWINGS_CURRENT        | 在上一個信用月份的金額
AMT_DRAWINGS_OTHER_CURRENT  | 上一個信用月份中其他提取數量
AMT_DRAWINGS_POS_CURRENT    | 在上一個信用額的月份內提取或購買商品的金額
AMT_INST_MIN_REGULARITY     | 上個月信貸的最低分期付款
AMT_PAYMENT_CURRENT         | 客戶在上個月的信用額度中支付了多少錢
AMT_PAYMENT_TOTAL_CURRENT   | 客戶在上個月的信貸總額中支付了多少錢
AMT_RECEIVABLE_PRINCIPAL    | 上次信貸的本金應收金額
AMT_RECIVABLE               | 先前信貸的應收金額
AMT_TOTAL_RECEIVABLE        | 先前信貸的應收總額
CNT_DRAWINGS_ATM_CURRENT    | 本月ATM在以前信用貸的提取數量
CNT_DRAWINGS_CURRENT        | 本月的提取數量與之前的信用額度相同
CNT_DRAWINGS_OTHER_CURRENT  | 本月的其他提取數量與之前的信用額度相同
CNT_DRAWINGS_POS_CURRENT    | 本月的貨物提取數量與之前的信用額度相同
CNT_INSTALMENT_MATURE_CUM   | 先前信用證的已付款分期付款數量
NAME_CONTRACT_STATUS        | 前一個信用卡的合約狀態（有效簽名，......）
SK_DPD                      | DPD（過期天數）前一個信用額的月份
SK_DPD_DEF                  | 該月的DPD（逾期天數）具有先前信用的容忍度（低貸款金額的債務被忽略）
--------------------------------------------------
檔名 : previous_application.csv
解釋 : 
1.All previous applications for Home Credit loans of clients who have loans in our sample.
2.There is one row for each previous application related to loans in our data sample.
--------------------------------------------------
SK_ID_PREV                  | 樣本貸款相關的歸屬信貸的先前信用的ID。 （我們樣本中的一筆貸款可以擁有0,1,2或更多以前的房屋貸款貸款）
SK_ID_CURR                  | 樣本貸款ID
NAME_CONTRACT_TYPE          | 上一個申請的合約產品類型（現金貸款，消費貸款[PROS]，......）
AMT_ANNUITY                 | 先前申請的年金
AMT_APPLICATION             | 客戶在之前的申請中提出多少信貸
AMT_CREDIT                  | 上一個申請的最終信用額度。這與AN APPLICATION的區別在於AMT APPLICATION的金額
AMT_DOWN_PAYMENT            | 先前申請的預付定金
AMT_GOODS_PRICE             | 客戶要求的商品價格（如果適用）在之前的申請
WEEKDAY_APPR_PROCESS_START  | 在一周的哪一天，客戶申請了以前的申請
HOUR_APPR_PROCESS_START     | 大約何時客戶申請上一個申請
FLAG_LAST_APPL_PER_CONTRACT | 如果它是上次合約最後一次申請，則標記。有時候，由於客戶或我們的職員的錯誤，可能會有更多的應用程序
NFLAG_LAST_APPL_IN_DAY      | 如果應用程序是客戶端每天的最後一個應用程序，則標記。有時客戶每天申請更多申請。在我們的系統中，一個應用程序在數據庫中兩次很少也可能是錯誤的
NFLAG_MICRO_CASH            | 小額信貸貸款
RATE_DOWN_PAYMENT           | 預付定金率按先前信貸標準化
RATE_INTEREST_PRIMARY       | 利率按先前信貸標準化
RATE_INTEREST_PRIVILEGED    | 利率按先前信貸標準化
NAME_CASH_LOAN_PURPOSE      | 現金貸款的目的
NAME_CONTRACT_STATUS        | 先前申請的合約狀態（已批准，已取消，......）
DAYS_DECISION               | 相對於當前的應用，是關於以前的申請的決定
NAME_PAYMENT_TYPE           | 客戶選擇為先前申請支付的付款方式
CODE_REJECT_REASON          | 為什麼先前的申請被拒絕
NAME_TYPE_SUITE             | 在申請之前的申請時，誰陪同客戶
NAME_CLIENT_TYPE            | 在申請之前的申請時，客戶是舊客戶還是新客戶
NAME_GOODS_CATEGORY         | 客戶在之前的申請中申請了哪些商品
NAME_PORTFOLIO              | 之前的申請是CASH，POS，CAR，？，
NUM_INSTALMENT_NUMBER       | 在哪一期觀察付款
DAYS_INSTALMENT             | 當應支付先前信貸的分期付款時（相對於當前貸款的申請日期）
DAYS_ENTRY_PAYMENT          | 實際支付以前信用的分期付款（相對於當前貸款的申請日期）
AMT_INSTALMENT              | 本批中先前信貸的規定分期付款金額是多少？
AMT_PAYMENT                 | 客戶在此分期付款的實際支付金額
--------------------------------------------------
檔名 : installments_payments.csv
解釋 : 
1.Repayment(還款) history for the previously disbursed(支出) credits in Home Credit related to the loans in our sample.
2.There is a) one row for every payment that was made plus b) one row each for missed payment.
3.One row is equivalent to one payment of one installment OR one installment corresponding to one payment of one previous Home Credit credit related to loans in our sample.
--------------------------------------------------
####
# Out:
#   File "<ipython-input-40-c03325116e15>", line 2
#     --------------------------------------------------
#                                                       ^
# SyntaxError: invalid syntax
